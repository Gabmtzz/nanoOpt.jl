# %%
using Pkg
Pkg.activate("../..")
# Out:
#   Activating project at `~/Documents/repos/nanoOpt.jl`

# %%
using Measures,LinearAlgebra,LazyGrids,LaTeXStrings,QuadGK,Plots; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
include("../../src/NanoOpt.jl")
# Out:
# KsspSlab (generic function with 1 method)

# %%
mat1 = material(1.0^2,1.0)
mat2 = material(epstable("silver"),1.0);

# %%
matScatter = [mat1; mat2];

# %%
w,d = 84.,10.
rc = 2.
Nc,Nw,Nd = 3,45,10;

# %%
rod₁ = Rod(w,d,rc,Nc,Nw,Nd,(44.5,0.))
rod₂ = Rod(w,d,rc,Nc,Nw,Nd,(-44.5,0.));

# %%
Structures = StructureC([rod₁; rod₂]);

# %%
xmin,ymin = -200.0,-100.0
xmax,ymax = 200.0,100.0
Δx,Δy = 10.0,10.
m= 2
xA = collect(xmin:Δx:xmax)
yA = collect(ymin:Δy:ymax);
Xin,Xout,Yin,Yout = getMesh(xA,yA,Structures);

# %%
gr()
X₁,Y₁ = getSurfPoints(rod₁)
X₂,Y₂ = getSurfPoints(rod₂)
scatter(Xout,Yout,c=:red)
scatter!(Xin,Yin,c=:blue)
plot!(X₁,Y₁,c=:black,lw=1.5,ls=:dash,label=L"\partial \Omega_1")
plot!(X₂,Y₂,c=:black,lw=1.5,ls=:dash,label=L"\partial \Omega_2",legend=:outerright)

# %%
dThr = 50.
m = 2
# Out:
# 2

# %%
i = 1

k0 = 2π/600
n₁ = mat1.n(k0)
n₂ = mat2.n(k0)
r = 500.
α = -90.
# Out:
# -90.0

# %%
Grf = GreenFunctions(matScatter,"Homo");

# %%
H,ϕ = getHϕ(m,Structures,k0,Grf,mat2.n,mat1.n,dThr,α);

# %%
gr()
plot(real.(H[:,1]),c=:black,lw=1.5,label=L"\Re\{ H(\mathbf{s}(t)) \}")
plot!(real.(ϕ[:,1])./k0,c=:blue,lw=1.5,ls=:dash,label=L"\Re\{ \phi(\mathbf{s}(t)) \}/ k_0",xlabel=L"t~[nm]",ylabel=L"Field",legend=:topright)

# %% [markdown]
# # ========================================

# %% [markdown]
# ## E

# %%
μ₀ = 1.25663706144e-6
ε₀ = 8.85418781762e-12


c1 = √(μ₀/ε₀)*(1/n₁)
c2 = √(μ₀/ε₀)*(1/n₂)
c2 = abs(c2)
# Out:
# 94.07475510889849

# %%
Eo = Get_E0(k0,n₁,Xout,Yout,α);

# %%
Eout = getEfieldOutside(k0,n₁,m,dThr,Structures,Xout,Yout,α,H,ϕ);

# %%
Ein = getEfieldInside(k0,n₂,m,dThr,Structures,Xin,Yin,α,H,ϕ);

# %%
eff = [Xout Yout norm.(Eout)./c1;
        Xin Yin norm.(Ein)./c2];

# %%
ind = sortperm(eff[:,2])

ogrde = eff[ind,:]


ind2 = sortperm(ogrde[:,1])

ogrde2 = ogrde[ind2,:];

# %%
imagenE = reshape(ogrde2[:,3],(length(yA),length(xA)));

# %%
plotly()
surface(xA,yA,imagenE)
# Out:
#     <div id="0dc38148-60ce-46a5-9402-84e75006bd64" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('0dc38148-60ce-46a5-9402-84e75006bd64', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "opacity": null,
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(2, 1, 10, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(2, 2, 12, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(2, 2, 14, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(3, 2, 16, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(4, 3, 18, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(4, 3, 20, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(5, 4, 23, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(6, 4, 25, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(7, 5, 27, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(8, 5, 29, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(9, 6, 31, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(10, 7, 34, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(11, 7, 36, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(12, 8, 38, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(13, 8, 41, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(14, 9, 43, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(16, 9, 45, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(17, 10, 48, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(18, 10, 50, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(20, 11, 52, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(21, 11, 55, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(22, 11, 57, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(24, 12, 60, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(25, 12, 62, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(27, 12, 65, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(28, 12, 67, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(30, 12, 69, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(31, 12, 72, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(33, 12, 74, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 12, 76, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(36, 12, 79, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(38, 12, 81, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(40, 11, 83, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(41, 11, 85, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(43, 11, 87, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(45, 11, 89, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(47, 10, 91, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(49, 10, 92, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(50, 10, 94, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(52, 10, 95, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(54, 9, 97, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(56, 9, 98, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(57, 9, 99, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(59, 9, 100, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(61, 9, 101, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(62, 9, 102, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(64, 10, 103, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(66, 10, 104, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(68, 10, 104, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(69, 10, 105, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(71, 11, 106, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(73, 11, 106, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(74, 12, 107, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(76, 12, 107, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(77, 13, 108, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(79, 13, 108, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(81, 14, 108, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(82, 14, 109, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(84, 15, 109, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(85, 15, 109, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(87, 16, 110, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(89, 16, 110, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(90, 17, 110, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(92, 18, 110, 1.000)"
#             ],
#             [
#                 0.26666666666666666,
#                 "rgba(93, 18, 110, 1.0

# %%
heatmap(xA,yA,imagenE)
# Out:
#     <div id="42e061d1-4dd5-46df-a1c4-b979e7f45446" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('42e061d1-4dd5-46df-a1c4-b979e7f45446', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(2, 1, 10, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(2, 2, 12, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(2, 2, 14, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(3, 2, 16, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(4, 3, 18, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(4, 3, 20, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(5, 4, 23, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(6, 4, 25, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(7, 5, 27, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(8, 5, 29, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(9, 6, 31, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(10, 7, 34, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(11, 7, 36, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(12, 8, 38, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(13, 8, 41, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(14, 9, 43, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(16, 9, 45, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(17, 10, 48, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(18, 10, 50, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(20, 11, 52, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(21, 11, 55, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(22, 11, 57, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(24, 12, 60, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(25, 12, 62, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(27, 12, 65, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(28, 12, 67, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(30, 12, 69, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(31, 12, 72, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(33, 12, 74, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 12, 76, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(36, 12, 79, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(38, 12, 81, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(40, 11, 83, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(41, 11, 85, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(43, 11, 87, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(45, 11, 89, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(47, 10, 91, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(49, 10, 92, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(50, 10, 94, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(52, 10, 95, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(54, 9, 97, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(56, 9, 98, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(57, 9, 99, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(59, 9, 100, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(61, 9, 101, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(62, 9, 102, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(64, 10, 103, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(66, 10, 104, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(68, 10, 104, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(69, 10, 105, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(71, 11, 106, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(73, 11, 106, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(74, 12, 107, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(76, 12, 107, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(77, 13, 108, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(79, 13, 108, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(81, 14, 108, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(82, 14, 109, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(84, 15, 109, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(85, 15, 109, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(87, 16, 110, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(89, 16, 110, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(90, 17, 110, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(92, 18, 110, 1.000)"
#             ],
#             [
#                 0.26666666666666666,
#                 "rgba(93, 18, 110, 1.000)"
#             ],

# %% [markdown]
# ## H

# %%
HOut = getHfielOutsie(k0,mat1,m,dThr,Structures,Xout,Yout,α,H,ϕ);

# %%
HIn = getHfieldInside(k0,mat2,m,dThr,Structures,Xin,Yin,α,H,ϕ);

# %%
grd = [Xout Yout abs.(HOut);
        Xin Yin abs.(HIn)];

# %%
ind = sortperm(grd[:,2])

ogrd = grd[ind,:]


ind2 = sortperm(ogrd[:,1])

ogrd2 = ogrd[ind2,:];

# %%
imagenH = reshape(ogrd2[:,3],(length(yA),length(xA)));

# %%
plotly()
surface(xA,yA,imagenH)
# Out:
#     <div id="77740bee-a409-4163-a3fd-20e048908279" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('77740bee-a409-4163-a3fd-20e048908279', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "opacity": null,
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(2, 1, 10, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(2, 2, 12, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(2, 2, 14, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(3, 2, 16, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(4, 3, 18, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(4, 3, 20, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(5, 4, 23, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(6, 4, 25, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(7, 5, 27, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(8, 5, 29, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(9, 6, 31, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(10, 7, 34, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(11, 7, 36, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(12, 8, 38, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(13, 8, 41, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(14, 9, 43, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(16, 9, 45, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(17, 10, 48, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(18, 10, 50, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(20, 11, 52, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(21, 11, 55, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(22, 11, 57, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(24, 12, 60, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(25, 12, 62, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(27, 12, 65, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(28, 12, 67, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(30, 12, 69, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(31, 12, 72, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(33, 12, 74, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 12, 76, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(36, 12, 79, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(38, 12, 81, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(40, 11, 83, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(41, 11, 85, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(43, 11, 87, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(45, 11, 89, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(47, 10, 91, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(49, 10, 92, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(50, 10, 94, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(52, 10, 95, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(54, 9, 97, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(56, 9, 98, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(57, 9, 99, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(59, 9, 100, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(61, 9, 101, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(62, 9, 102, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(64, 10, 103, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(66, 10, 104, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(68, 10, 104, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(69, 10, 105, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(71, 11, 106, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(73, 11, 106, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(74, 12, 107, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(76, 12, 107, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(77, 13, 108, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(79, 13, 108, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(81, 14, 108, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(82, 14, 109, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(84, 15, 109, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(85, 15, 109, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(87, 16, 110, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(89, 16, 110, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(90, 17, 110, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(92, 18, 110, 1.000)"
#             ],
#             [
#                 0.26666666666666666,
#                 "rgba(93, 18, 110, 1.0

# %%
heatmap(xA,yA,imagenH)
# Out:
#     <div id="d3c3bf51-2e0a-4a56-a647-16f793dbcee1" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['plotly'], function (Plotly) {
#
#     Plotly.newPlot('d3c3bf51-2e0a-4a56-a647-16f793dbcee1', [
#     {
#         "showlegend": false,
#         "xaxis": "x",
#         "colorbar": {
#             "y": 0.513888888888889,
#             "title": "",
#             "len": 0.9525371828521435,
#             "x": 0.7615339749198018
#         },
#         "name": "y1",
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(2, 1, 10, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(2, 2, 12, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(2, 2, 14, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(3, 2, 16, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(4, 3, 18, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(4, 3, 20, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(5, 4, 23, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(6, 4, 25, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(7, 5, 27, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(8, 5, 29, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(9, 6, 31, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(10, 7, 34, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(11, 7, 36, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(12, 8, 38, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(13, 8, 41, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(14, 9, 43, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(16, 9, 45, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(17, 10, 48, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(18, 10, 50, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(20, 11, 52, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(21, 11, 55, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(22, 11, 57, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(24, 12, 60, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(25, 12, 62, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(27, 12, 65, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(28, 12, 67, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(30, 12, 69, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(31, 12, 72, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(33, 12, 74, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 12, 76, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(36, 12, 79, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(38, 12, 81, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(40, 11, 83, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(41, 11, 85, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(43, 11, 87, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(45, 11, 89, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(47, 10, 91, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(49, 10, 92, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(50, 10, 94, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(52, 10, 95, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(54, 9, 97, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(56, 9, 98, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(57, 9, 99, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(59, 9, 100, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(61, 9, 101, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(62, 9, 102, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(64, 10, 103, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(66, 10, 104, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(68, 10, 104, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(69, 10, 105, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(71, 11, 106, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(73, 11, 106, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(74, 12, 107, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(76, 12, 107, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(77, 13, 108, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(79, 13, 108, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(81, 14, 108, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(82, 14, 109, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(84, 15, 109, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(85, 15, 109, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(87, 16, 110, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(89, 16, 110, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(90, 17, 110, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(92, 18, 110, 1.000)"
#             ],
#             [
#                 0.26666666666666666,
#                 "rgba(93, 18, 110, 1.000)"
#             ],
